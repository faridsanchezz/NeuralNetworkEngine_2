# %%
from Activations import *
from NeuronalNetwork import *
from Optimizers import *
from LossFunctions import *
from myDatasets import *
from MetricUtils import *

# %% [markdown]
# ### Dataset MNIST
# 789 features
# 10 classes

# %%
path_mnist_data = "../MNIST_data"
X_train, X_test, y_train, y_test = load_and_preprocess_data_mnist(path_mnist_data)

print("Shape of X:", X_train.shape)
print("Shape of y:", y_train.shape)
print("Shape of y:", X_test.shape)
print("Shape of y:", y_test.shape)
# Out:
# Shape of X: (60000, 784)
# Shape of y: (60000, 10)
# Shape of y: (10000, 784)
# Shape of y: (10000, 10)

# %%
# to initialize the weights you can use different options: he, xavier, normal
layers = [
    DenseLayer(input_size=784, output_size=128, init_method='he'),
    ReLU(),
    DenseLayer(input_size=128, output_size=64, init_method='he'),
    ReLU(),
    DenseLayer(input_size=64, output_size=10, init_method='he'),
    Softmax()
]

network = NeuralNetwork(
        layers=layers,
        loss_function=MSE(),
        optimizer=Adam(learning_rate=0.001)
    )


training_history = train_network(
    network=network,
    X=X_train,
    y=y_train,
    epochs=100,
    batch_size=100,
    early_stopping_patience=5,
    validation_split=0.2,
    verbose=2
)


y_pred = network.predict(X_test)
print(evaluate_model(y_pred, y_test))
confusionMatrix(y_test, y_pred)
display_training_history(training_history)
# Out:
# Epoch 0/100, Val Loss: 0.0088, Val Acc: 0.9437
# Epoch 1/100, Val Loss: 0.0072, Val Acc: 0.9528
# Epoch 2/100, Val Loss: 0.0058, Val Acc: 0.9618
# Epoch 3/100, Val Loss: 0.0052, Val Acc: 0.9662
# Epoch 4/100, Val Loss: 0.0046, Val Acc: 0.9707
# Epoch 5/100, Val Loss: 0.0047, Val Acc: 0.9694
# Epoch 6/100, Val Loss: 0.0042, Val Acc: 0.9732
# Epoch 7/100, Val Loss: 0.0046, Val Acc: 0.9711
# Epoch 8/100, Val Loss: 0.0041, Val Acc: 0.9744
# Epoch 9/100, Val Loss: 0.0044, Val Acc: 0.9732
# Epoch 10/100, Val Loss: 0.0041, Val Acc: 0.9750
# Epoch 11/100, Val Loss: 0.0040, Val Acc: 0.9746
# Epoch 12/100, Val Loss: 0.0044, Val Acc: 0.9722
# Epoch 13/100, Val Loss: 0.0045, Val Acc: 0.9712
# Epoch 14/100, Val Loss: 0.0040, Val Acc: 0.9759
# Epoch 15/100, Val Loss: 0.0039, Val Acc: 0.9762
# Epoch 16/100, Val Loss: 0.0045, Val Acc: 0.9724
# Epoch 17/100, Val Loss: 0.0041, Val Acc: 0.9735
# Epoch 18/100, Val Loss: 0.0043, Val Acc: 0.9737
# Epoch 19/100, Val Loss: 0.0039, Val Acc: 0.9752
# Early stopping triggered at epoch 20
# {'accuracy': 0.9768, 'precision': 0.9770415232048106, 'recall': 0.9768, 'f1': 0.9768330859323149}

# %% [markdown]
# ### Dastaset Iris
# 4 features
# 3 classes

# %%
X_train, X_test, y_train, y_test = load_and_preprocess_data_iris()

print("Shape of X:", X_train.shape)
print("Shape of y:", y_train.shape)
print("Shape of y:", X_test.shape)
print("Shape of y:", y_test.shape)
# Out:
# Shape of X: (120, 4)
# Shape of y: (120, 3)
# Shape of y: (30, 4)
# Shape of y: (30, 3)

# %%
X_train, X_test, y_train, y_test = load_and_preprocess_data_iris()

layers = [
    DenseLayer(input_size=4, output_size=128, init_method='he'),
    ReLU(),
    DenseLayer(input_size=128, output_size=64, init_method='he'),
    ReLU(),
    DenseLayer(input_size=64, output_size=3, init_method='he'),
    Softmax()
]

network = NeuralNetwork(
        layers=layers,
        loss_function=MSE(),
        optimizer=Adam(learning_rate=0.001)
    )


training_history = train_network(
    network=network,
    X=X_train,
    y=y_train,
    epochs=100,
    batch_size=40,
    early_stopping_patience=5,
    validation_split=0.2,
    verbose=2
)


y_pred = network.predict(X_test)
print(evaluate_model(y_pred, y_test))
confusionMatrix(y_test, y_pred)
display_training_history(training_history)
# Out:
# Epoch 0/100, Val Loss: 0.1918, Val Acc: 0.5000
# Epoch 1/100, Val Loss: 0.1825, Val Acc: 0.5000
# Epoch 2/100, Val Loss: 0.1688, Val Acc: 0.5000
# Epoch 3/100, Val Loss: 0.1578, Val Acc: 0.5000
# Epoch 4/100, Val Loss: 0.1512, Val Acc: 0.5000
# Epoch 5/100, Val Loss: 0.1447, Val Acc: 0.5000
# Epoch 6/100, Val Loss: 0.1406, Val Acc: 0.5000
# Epoch 7/100, Val Loss: 0.1386, Val Acc: 0.5000
# Epoch 8/100, Val Loss: 0.1344, Val Acc: 0.5000
# Epoch 9/100, Val Loss: 0.1327, Val Acc: 0.5000
# Epoch 10/100, Val Loss: 0.1255, Val Acc: 0.5417
# Epoch 11/100, Val Loss: 0.1199, Val Acc: 0.8333
# Epoch 12/100, Val Loss: 0.1167, Val Acc: 0.8750
# Epoch 13/100, Val Loss: 0.1161, Val Acc: 0.8333
# Epoch 14/100, Val Loss: 0.1216, Val Acc: 0.5000
# Epoch 15/100, Val Loss: 0.1206, Val Acc: 0.5000
# Epoch 16/100, Val Loss: 0.1087, Val Acc: 0.8333
# Epoch 17/100, Val Loss: 0.1040, Val Acc: 0.9167
# Epoch 18/100, Val Loss: 0.1017, Val Acc: 0.9167
# Epoch 19/100, Val Loss: 0.1017, Val Acc: 0.8750
# Epoch 20/100, Val Loss: 0.1019, Val Acc: 0.8333
# Epoch 21/100, Val Loss: 0.0996, Val Acc: 0.8333
